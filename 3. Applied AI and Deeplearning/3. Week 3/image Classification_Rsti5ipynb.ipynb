# %%
'''Trains a simple deep NN on the MNIST dataset.

Gets to 98.40% test accuracy after 20 epochs
(there is *a lot* of margin for parameter tuning).
2 seconds per epoch on a K520 GPU.
'''

from __future__ import print_function

import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.optimizers import RMSprop
from keras.layers import Conv2D, MaxPooling2D

batch_size = 128
num_classes = 10
epochs = 20

# the data, shuffled and split between train and test sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()

#x_train = x_train.reshape(60000, 784)
#x_test = x_test.reshape(10000, 784)
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

#Please construct the following neural network and report accuracy after training
#Layer 1: 2D Convolution with 32 hidden neurons, kernel 3 by 3, relu activation, input_shape (28,28,1)
#Layer 2: 2D MaxPooling, pool_size 2 by 2
#Layer 3: Flatten (Hint: model.add(Flatten()))
#Layer 4 Softmax Output Layer according to the problem (output vector)


model = Sequential()
#your_code_goes_here
model.add(Conv2D(32, kernel_size=(3,3),activation='relu', input_shape=(28,28,1)))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Flatten())
model.add(Dense(num_classes, activation='softmax'))
"""
#Please delete this code <
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
#> Please delete this code 
"""
model.summary()

model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])


#some learners constantly reported 502 errors in Watson Studio. 
#This is due to the limited resources in the free tier and the heavy resource consumption of Keras.
#This is a workaround to limit resource consumption

from keras import backend as K

#K.set_session(K.tf.Session(config=K.tf.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)))
K.set_session(K.tf.compat.v1.Session(config=K.tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)))

history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 60000 train samples
# 10000 test samples
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 32)       0
#  )
#
#  flatten (Flatten)           (None, 5408)              0
#
#  dense (Dense)               (None, 10)                54090
#
# =================================================================
# Total params: 54,410
# Trainable params: 54,410
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 469/469 [==============================] - 20s 40ms/step - loss: 0.3398 - accuracy: 0.9039 - val_loss: 0.1908 - val_accuracy: 0.9458
# Epoch 2/20
# 469/469 [==============================] - 18s 39ms/step - loss: 0.1479 - accuracy: 0.9589 - val_loss: 0.1080 - val_accuracy: 0.9688
# Epoch 3/20
# 469/469 [==============================] - 19s 41ms/step - loss: 0.0968 - accuracy: 0.9727 - val_loss: 0.0784 - val_accuracy: 0.9754
# Epoch 4/20
# 469/469 [==============================] - 20s 43ms/step - loss: 0.0749 - accuracy: 0.9791 - val_loss: 0.0698 - val_accuracy: 0.9771
# Epoch 5/20
# 469/469 [==============================] - 20s 42ms/step - loss: 0.0638 - accuracy: 0.9816 - val_loss: 0.0622 - val_accuracy: 0.9800
# Epoch 6/20
# 469/469 [==============================] - 18s 39ms/step - loss: 0.0561 - accuracy: 0.9840 - val_loss: 0.0589 - val_accuracy: 0.9807
# Epoch 7/20
# 469/469 [==============================] - 19s 40ms/step - loss: 0.0511 - accuracy: 0.9857 - val_loss: 0.0560 - val_accuracy: 0.9815
# Epoch 8/20
# 469/469 [==============================] - 19s 42ms/step - loss: 0.0467 - accuracy: 0.9868 - val_loss: 0.0591 - val_accuracy: 0.9806
# Epoch 9/20
# 469/469 [==============================] - 18s 39ms/step - loss: 0.0434 - accuracy: 0.9879 - val_loss: 0.0530 - val_accuracy: 0.9823
# Epoch 10/20
# 469/469 [==============================] - 19s 40ms/step - loss: 0.0407 - accuracy: 0.9883 - val_loss: 0.0548 - val_accuracy: 0.9834
# Epoch 11/20
# 469/469 [==============================] - 18s 39ms/step - loss: 0.0377 - accuracy: 0.9893 - val_loss: 0.0526 - val_accuracy: 0.9841
# Epoch 12/20
# 469/469 [==============================] - 19s 41ms/step - loss: 0.0364 - accuracy: 0.9899 - val_loss: 0.0507 - val_accuracy: 0.9843
# Epoch 13/20
# 469/469 [==============================] - 21s 44ms/step - loss: 0.0338 - accuracy: 0.9911 - val_loss: 0.0518 - val_accuracy: 0.9835
# Epoch 14/20
# 469/469 [==============================] - 18s 38ms/step - loss: 0.0323 - accuracy: 0.9912 - val_loss: 0.0547 - val_accuracy: 0.9836
# Epoch 15/20
# 469/469 [==============================] - 18s 39ms/step - loss: 0.0308 - accuracy: 0.9919 - val_loss: 0.0542 - val_accuracy: 0.9836
# Epoch 16/20
# 469/469 [==============================] - 21s 44ms/step - loss: 0.0293 - accuracy: 0.9919 - val_loss: 0.0528 - val_accuracy: 0.9837
# Epoch 17/20
# 469/469 [==============================] - 20s 43ms/step - loss: 0.0280 - accuracy: 0.9923 - val_loss: 0.0521 - val_accuracy: 0.9843
# Epoch 18/20
# 469/469 [==============================] - 20s 42ms/step - loss: 0.0265 - accuracy: 0.9930 - val_loss: 0.0546 - val_accuracy: 0.9833
# Epoch 19/20
# 469/469 [==============================] - 19s 41ms/step - loss: 0.0257 - accuracy: 0.9931 - val_loss: 0.0563 - val_accuracy: 0.9832
# Epoch 20/20
# 469/469 [==============================] - 20s 43ms/step - loss: 0.0246 - accuracy: 0.9936 - val_loss: 0.0545 - val_accuracy: 0.9840
# Test loss: 0.05450402945280075
# Test accuracy: 0.984000027179718
